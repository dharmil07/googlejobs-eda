# %% [markdown]
# # Exploratory Data Analysis of what kind of Jobs and Job Locations are provided by Google

# %% [raw]
# This dataset is collected using Selenium by scraping all of the jobs text for Google Career site.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
google = pd.read_csv('C:\Dharmil Imp\Projects\Google Job\job_skills.csv')

google.shape
# Out:
# (1250, 7)

# %%
google.head(10)
# Out:
#   Company                                              Title  \
# 0  Google                       Google Cloud Program Manager
# 1  Google  Supplier Development Engineer (SDE), Cable/Con...
# 2  Google  Data Analyst, Product and Tools Operations, Go...
# 3  Google            Developer Advocate, Partner Engineering
# 4  Google     Program Manager, Audio Visual (AV) Deployments
# 5  Google  Associate Account Strategist (Czech/Slovak), G...
# 6  Google  Supplier Development Engineer, Camera, Consume...
# 7  Google  Strategic Technology Partner Manager, Healthca...
# 8  Google    Manufacturing Business Manager, Google Hardware
# 9  Google  Solutions Architect, Healthcare and Life Scien...
#
#                        Category                          Location  \
# 0            Program Management                         Singapore
# 1  Manufacturing & Supply Chain                   Shanghai, China
# 2           Technical Solutions       New York, NY, United States
# ...

# %%
google.columns
# Out:
# Index(['Company', 'Title', 'Category', 'Location', 'Responsibilities',
#        'Minimum Qualifications', 'Preferred Qualifications'],
#       dtype='object')

# %%
google.describe()
# Out:
#        Company                 Title                    Category  \
# count     1250                  1250                        1250
# unique       2                   794                          23
# top     Google  Business Intern 2018  Sales & Account Management
# freq      1227                    35                         168
#
#                                 Location  \
# count                               1250
# unique                                92
# top     Mountain View, CA, United States
# freq                                 190
#
#                                          Responsibilities  \
# count                                                1235
# unique                                                801
# top     Responsibilities and detailed projects will be...
# freq                                                   33
#
#                                    Minimum Qualifications  \
# count                                                1236
# ...

# %%
google.isnull().any()
# Out:
# Company                     False
# Title                       False
# Category                    False
# Location                    False
# Responsibilities             True
# Minimum Qualifications       True
# Preferred Qualifications     True
# dtype: bool

# %%
# Companies involved

plt.rcParams['figure.figsize'] = (7, 9)
google['Company'].value_counts().plot.bar(color = 'blue')
plt.title('The companies Involved for recruitment', fontsize = 20)
plt.xlabel('Names of companies', fontsize = 15)
plt.show()

# %%
# Most Popular 20 Job Titles of Google

plt.rcParams['figure.figsize'] = (19, 10)
google['Title'].value_counts().sort_values(ascending = False).head(20).plot.bar(color = 'pink')
plt.title("Most Popular 20 Job Titles of Google", fontsize = 20)
plt.xlabel('Names of Job Titles', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
#Most Popular 20 Job Categories of Google

plt.rcParams['figure.figsize'] = (15, 6)
google['Category'].value_counts().sort_values(ascending = False).head(20).plot.bar(color = 'lightgreen')
plt.title("Most Popular 20 Job Categories of Google", fontsize = 20)
plt.xlabel('Names of Job Categories', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
# Most Popular 20 Job Locations of Google

plt.rcParams['figure.figsize'] = (17, 6)
google['Location'].value_counts().sort_values(ascending = False).head(20).plot.bar(color = 'lightblue')
plt.title("Most Popular 20 Job Locations of Google", fontsize = 20)
plt.xlabel('Names of Job Locations', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
# Places with Most Jobs

from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'white').generate(str(google['Location']))

print(wordcloud)
plt.rcParams['figure.figsize'] = (12, 12)
plt.axis('off')
plt.title('Places with Most Jobs', fontsize = 30)
plt.imshow(wordcloud)
plt.show()

# %%
# Most Popular Responsibilities

from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'pink', max_words = 100).generate(str(google['Responsibilities']))

print(wordcloud)
plt.rcParams['figure.figsize'] = (15, 15)
plt.axis('off')
plt.imshow(wordcloud)
plt.title('Most Popular Responsibilities', fontsize = 30)
plt.show()

# %%
# Most Popular Educational Requirements

from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'cyan', max_words = 80).generate(str(google['Minimum Qualifications']))

print(wordcloud)
plt.rcParams['figure.figsize'] = (12, 12)
plt.axis('off')
plt.imshow(wordcloud)
plt.title('Most Popular Educational Requirements', fontsize = 30)
plt.show()

# %%
# 

from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'orange', max_words = 80).generate(str(google['Preferred Qualifications']))

print(wordcloud)
plt.rcParams['figure.figsize'] = (17, 12)
plt.axis('off')
plt.imshow(wordcloud)
plt.title('Most Popular Preferred Requirements', fontsize = 30)
plt.show()
